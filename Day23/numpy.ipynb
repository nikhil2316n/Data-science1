# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pit
import math

# %%
x=np.linspace(0,2*math.pi,1000)

# %%
y=np.sin(x)
y_1=np.cos(x)

# %%
pit.plot(x,y)
pit.plot(x,y_1)
pit.grid(True)
pit.show()
