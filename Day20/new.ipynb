# %%
print("hello")
# Out:
# hello

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
sns.scatterplot(x=np.array([2,3,9]),y=np.array([4,2,8]),s=250,marker="*",color="r")
plt.grid(True)
plt.show()
